# %%
import pandas as pd
df = pd.read_pickle("../data/proccessed/retail_after_format.pkl")

# %%
df.head(30)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %% [markdown]
# #add the new series time columns this step called basic feature engineering

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Week'] = df['Date'].dt.isocalendar().week
df['Quarter'] = df['Date'].dt.quarter
df['dayOfYear'] = df['Date'].dt.dayofyear
df['IsMonthStart'] = df['Date'].dt.is_month_start.astype(int)
df['IsMonthEnd'] = df['Date'].dt.is_month_end.astype(int)

# %%
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  Year  Month  Week  Quarter  dayOfYear  \
# 0  211.096358         8.106  2010      2     5        1         36
# 1  211.242170         8.106  2010      2     6        1         43
# 2  211.289143         8.106  2010      2     7        1         50
# 3  211.319643         8.106  2010      2     8        1         57
# 4  211.350143         8.106  2010      3     9        1         64
#
#    IsMonthStart  IsMonthEnd
# 0             0           0
# 1             0           0
# 2             0           0
# ...

# %% [markdown]
# #let's again see if there any null in those data

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# Year            0
# Month           0
# Week            0
# Quarter         0
# dayOfYear       0
# IsMonthStart    0
# IsMonthEnd      0
# dtype: int64

# %% [markdown]
# #check the sorted of the data for store

# %%
df = df.sort_values(by = ['Store', 'Date']).reset_index(drop = True)

# %%
df.describe()
# Out:
#              Store                 Date  Weekly_Sales  Holiday_Flag  \
# count  6435.000000                 6435  6.435000e+03   6435.000000
# mean     23.000000  2011-06-17 00:00:00  1.046965e+06      0.069930
# min       1.000000  2010-02-05 00:00:00  2.099862e+05      0.000000
# 25%      12.000000  2010-10-08 00:00:00  5.533501e+05      0.000000
# 50%      23.000000  2011-06-17 00:00:00  9.607460e+05      0.000000
# 75%      34.000000  2012-02-24 00:00:00  1.420159e+06      0.000000
# max      45.000000  2012-10-26 00:00:00  3.818686e+06      1.000000
# std      12.988182                  NaN  5.643666e+05      0.255049
#
#        Temperature   Fuel_Price          CPI  Unemployment         Year  \
# count  6435.000000  6435.000000  6435.000000   6435.000000  6435.000000
# mean     60.663782     3.358607   171.578394      7.999151  2010.965035
# min      -2.060000     2.472000   126.064000      3.879000  2010.000000
# ...

# %% [markdown]
# #check the duplicate for the same store in the same date

# %%
df.duplicated(subset = ['Store', 'Date']).sum()
# Out:
# np.int64(0)

# %%
df.to_pickle("../data/proccessed/retail_clean.pkl")
